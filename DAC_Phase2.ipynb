# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
df=pd.read_csv(r"C:\Users\Welcome\Downloads\daily-website-visitors.csv")
df
# Out:
#        Row        Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 0        1     Sunday            1  9/14/2014      2,146         1,582
# 1        2     Monday            2  9/15/2014      3,621         2,528
# 2        3    Tuesday            3  9/16/2014      3,698         2,630
# 3        4  Wednesday            4  9/17/2014      3,667         2,614
# 4        5   Thursday            5  9/18/2014      3,316         2,366
# ...    ...        ...          ...        ...        ...           ...
# 2162  2163   Saturday            7  8/15/2020      2,221         1,696
# 2163  2164     Sunday            1  8/16/2020      2,724         2,037
# 2164  2165     Monday            2  8/17/2020      3,456         2,638
# 2165  2166    Tuesday            3  8/18/2020      3,581         2,683
# 2166  2167  Wednesday            4  8/19/2020      2,064         1,564
#
#      First.Time.Visits Returning.Visits
# 0                1,430              152
# ...

# %%
df.head()
# Out:
#    Row        Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 0    1     Sunday            1  9/14/2014      2,146         1,582
# 1    2     Monday            2  9/15/2014      3,621         2,528
# 2    3    Tuesday            3  9/16/2014      3,698         2,630
# 3    4  Wednesday            4  9/17/2014      3,667         2,614
# 4    5   Thursday            5  9/18/2014      3,316         2,366
#
#   First.Time.Visits Returning.Visits
# 0             1,430              152
# 1             2,297              231
# 2             2,352              278
# 3             2,327              287
# 4             2,130              236

# %%
x = np.random.randint(low=1, high=11, size=30)
y = x + np.random.randint(1, 6, size=30)

sb.set_style('darkgrid')

plt.scatter(x=x, y=y, color='orange')

# %%
sb.set_style('white')
sb.set_context('talk')
plt.scatter(x=x, y=y, color='orange')

# %%
sb.rugplot(df['Day'])
# Out:
# <Axes: xlabel='Day'>

# %%
sb.jointplot(x="Unique.Visits",y="First.Time.Visits", data=df)

# %%
sb.pairplot(df)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
df.isnull().sum()
# Out:
# Row                  0
# Day                  0
# Day.Of.Week          0
# Date                 0
# Page.Loads           0
# Unique.Visits        0
# First.Time.Visits    0
# Returning.Visits     0
# dtype: int64

# %%
df.interpolate()
# Out:
#        Row        Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 0        1     Sunday            1  9/14/2014      2,146         1,582
# 1        2     Monday            2  9/15/2014      3,621         2,528
# 2        3    Tuesday            3  9/16/2014      3,698         2,630
# 3        4  Wednesday            4  9/17/2014      3,667         2,614
# 4        5   Thursday            5  9/18/2014      3,316         2,366
# ...    ...        ...          ...        ...        ...           ...
# 2162  2163   Saturday            7  8/15/2020      2,221         1,696
# 2163  2164     Sunday            1  8/16/2020      2,724         2,037
# 2164  2165     Monday            2  8/17/2020      3,456         2,638
# 2165  2166    Tuesday            3  8/18/2020      3,581         2,683
# 2166  2167  Wednesday            4  8/19/2020      2,064         1,564
#
#      First.Time.Visits Returning.Visits
# 0                1,430              152
# ...

# %%
sns.lmplot(x="Row",y="Day.Of.Week",data=df)

# %%
x1=df.iloc[:,0:1]
x1
# Out:
#        Row
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 2162  2163
# 2163  2164
# 2164  2165
# 2165  2166
# 2166  2167
#
# [2167 rows x 1 columns]

# %%
y1=df.iloc[:,2:3]
y1
# Out:
#       Day.Of.Week
# 0               1
# 1               2
# 2               3
# 3               4
# 4               5
# ...           ...
# 2162            7
# 2163            1
# 2164            2
# 2165            3
# 2166            4
#
# [2167 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_poly=LinearRegression() #making linear model
linear_poly.fit(x1,y1)
# Out:
# LinearRegression()

# %%
linear_poly.predict([[11]])
# Out:
# C:\Users\Welcome\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[3.99448796]])

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=3)

# %%
x1
# Out:
#        Row
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 2162  2163
# 2163  2164
# 2164  2165
# 2165  2166
# 2166  2167
#
# [2167 rows x 1 columns]

# %%
x1_poly=poly.fit_transform(x1)

# %%
x1_poly
# Out:
# array([[1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#        [1.00000000e+00, 2.00000000e+00, 4.00000000e+00, 8.00000000e+00],
#        [1.00000000e+00, 3.00000000e+00, 9.00000000e+00, 2.70000000e+01],
#        ...,
#        [1.00000000e+00, 2.16500000e+03, 4.68722500e+06, 1.01478421e+10],
#        [1.00000000e+00, 2.16600000e+03, 4.69155600e+06, 1.01619103e+10],
#        [1.00000000e+00, 2.16700000e+03, 4.69588900e+06, 1.01759915e+10]])

# %%
reg2=LinearRegression() #making polynmial model
reg2.fit(x1_poly,y1)
# Out:
# LinearRegression()

# %%
plt.scatter(x1,y1,color='blue')
plt.plot(x1,linear_poly.predict(x1),color='red')
plt.xlabel("Row")
plt.ylabel("Day.Of.Week")
plt.title("Using Linear Regression")
# Out:
# Text(0.5, 1.0, 'Using Linear Regression')

# %%
plt.scatter(x1,y1,color='blue')
plt.plot(x1,reg2.predict(poly.fit_transform(x1)),color='red')
plt.xlabel("Row")
plt.ylabel("Day.Of.Week")
plt.title("Using Polynomial Regression")
# Out:
# Text(0.5, 1.0, 'Using Polynomial Regression')

# %%
reg2.predict(poly.fit_transform([[11]])) #using degree 2
# Out:
# array([[3.97494439]])

# %%
reg2.predict(poly.fit_transform([[11]])) #using degree 3
# Out:
# array([[3.97494439]])

# %%
reg2.predict(poly.fit_transform([[11]])) #using degree 5
# Out:
# array([[3.97494439]])

# %%
df["Day"].unique()
# Out:
# array(['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
#        'Saturday'], dtype=object)

# %%
df["Day"].replace({'Sunday':1, 'Monday':2, 'Tuesday':3, 'Wednesday':4, 'Thursday':5, 'Friday':6, 'Saturday':7},inplace=True)

# %%
df
# Out:
#        Row  Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 0        1    1            1  9/14/2014      2,146         1,582
# 1        2    2            2  9/15/2014      3,621         2,528
# 2        3    3            3  9/16/2014      3,698         2,630
# 3        4    4            4  9/17/2014      3,667         2,614
# 4        5    5            5  9/18/2014      3,316         2,366
# ...    ...  ...          ...        ...        ...           ...
# 2162  2163    7            7  8/15/2020      2,221         1,696
# 2163  2164    1            1  8/16/2020      2,724         2,037
# 2164  2165    2            2  8/17/2020      3,456         2,638
# 2165  2166    3            3  8/18/2020      3,581         2,683
# 2166  2167    4            4  8/19/2020      2,064         1,564
#
#      First.Time.Visits Returning.Visits
# 0                1,430              152
# 1                2,297              231
# 2                2,352              278
# ...
